# %%
import numpy as np 
import pandas as pd
import torch
import torch.nn as nn
from ModelLarge import ModelLarge
from ModelDeep import ModelDeep
from TestPerformance import test_performanceNN
from VisualizeError import *
from joblib import load, dump
from ParallelGPR import *

#let's load the dedicated dataset
dataset = "HestonPlotError.csv"
df = pd.read_csv(dataset)
features = df.columns[2:]

# %%
#load the Neural Networks models and visualize the errors
#Model Large trained on 1milion observations 
mod = torch.load("modelNNLarge.pt")
title = "Neural Network Large"
visualize_errorNN(df, mod, features, title)

# %%
#load the Neural Networks models and visualize the errors
#Model Large trained on 10k observations 
mod = torch.load("modelNNLarge_SmallTrain.pt")
title = "Neural Network Large"
visualize_errorNN(df, mod, features, title)

# %%
#load the Neural Networks models and visualize the errors
#Model Deep trained on 1milion observations 
mod = torch.load("modelNNDeep.pt")
title = "Neural Network Deep"
visualize_errorNN(df, mod, features,title)

# %%
#load the Neural Networks models and visualize the errors
#Model Deep trained on 10k observations 
mod = torch.load("modelNNDeep_XL.pt")
title = "Neural Network Deep"
visualize_errorNN(df, mod, features,title)

# %%
#load the GPR trained on 5k observations
mod = load("GPR5000.joblib")
title = "GPR 5000"
visualize_errorGPR(df, mod, features, title)

# %%
#load the GPR trained on 10k observations
mod = load("GPR10000.joblib")
title = "GPR 10000"
visualize_errorGPR(df, mod, features, title)

# %%
#load the GPR trained on 20k observations
mod = load("GPR20000.joblib")
title = "GPR 20000"
visualize_errorGPR(df, mod, features, title)

# %%
#load the ParallelGPR trained on 100k observations 
mod = ParallelGPR(40)
mod.load("Parallel40")
title = "P-GPR 40"
visualize_errorGPR(df, mod, features, title)

# %%
#load the RF trained on 100k observations 
mod = load("RFXL.joblib")
title = "Random Forest"
visualize_errorGPR(df, mod, features, title)

# %%
#load the RF trained on 1mln observations 
mod = load("RFXL.joblib")
title = "Random Forest"
visualize_errorGPR(df, mod, features, title)
